# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Milestone Project 2 - Blackjack Game
# In this milestone project you will be creating a Complete BlackJack Card Game in Python.
#
# Here are the requirements:
#
# * You need to create a simple text-based [BlackJack](https://en.wikipedia.org/wiki/Blackjack) game
# * The game needs to have one player versus an automated dealer.
# * The player can stand or hit.
# * The player must be able to pick their betting amount.
# * You need to keep track of the player's total money.
# * You need to alert the player of wins, losses, or busts, etc...
#
# And most importantly:
#
# * **You must use OOP and classes in some portion of your game. You can not just use functions in your game. Use classes to help you define the Deck and the Player's hand. There are many right ways to do this, so explore it well!**
#
#
# Feel free to expand this game. Try including multiple players. Try adding in Double-Down and card splits! Remember to you are free to use any resources you want and as always:
#
# # HAVE FUN!

# %%
import random
import sys

# %%
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':10, 'Queen':10, 'King':10, 'Ace':11}

# %%
def new_game():
    game_state = input('Would you like to play another hand? If so return "Y"')
    
    if game_state=='Y':
        return True 
    else: 
        return False

# %%
def my_print(text):
    sys.stdout.write(str(text))
    sys.stdout.flush()

# %%
class Card():
    def __init__(self, rank, suit):
        self.suit=suit
        self.rank=rank 
        self.value=values[rank]

    def __str__(self):
        return self.rank + " of "+self.suit

# %%
class Deck(): 

    def __init__(self):
        self.all_cards = []
        
        for suit in suits:
            for rank in ranks:
                new_card=Card(rank, suit)
                self.all_cards.append(new_card)
        
    def shuffle(self):
        random.shuffle(self.all_cards)
    
    def deal(self): 
        return self.all_cards.pop()

# %%
class Player():

    def __init__(self): 
        self.hand = []
        self.chips = 150
        self.hand_val= 0

    def __str__(self): 
        return "The Player has: " + self.hand_print()+"\n"
        
    def hand_print(self):
        final_hand_string = ""
        for i in range(0, len(self.hand)):
            addition = str(self.hand[i])+", "
            final_hand_string=final_hand_string+addition
        return final_hand_string[0:-2]

    def bet(self): 
        self.bet_val = 'Wrong'
        self.in_rage=True
        self.allowable_range=list(range(0,self.chips))
        #print(self.allowable_range)

        #Check if we have a digit
        while self.bet_val.isdigit() == False or self.in_range==False:
            self.bet_val = input("Please bet chips up to your max: ")

        #if not a digit, loop re runs until we get a digit
            if self.bet_val.isdigit() == False:
                print('Please enter a DIGIT') 

        #if digit and in allowed range, stops loop
            if self.bet_val.isdigit() == True:
                if int(self.bet_val) in self.allowable_range:
                    self.chips=self.chips-int(self.bet_val)
                    self.in_range = True 
                else:
                    print('Please bet an allowable chip quantity')
                    self.in_range = False 
        
        return int(self.bet_val)
    
    def add_to_chips(self, val_chips): 
        self.val_chips = val_chips
        self.chips = self.chips + self.val_chips
        print("The Player now has: " + str(self.chips) + " chips")

    def hand_calc(self):
        self.hand_val=0
        for j in range(0, len(self.hand)):
            self.hand_val=self.hand[j].value+self.hand_val
        return self.hand_val
    
    def ace_check(self):
        has_ace = False
        for k in range(0, len(self.hand)):
            if self.hand[k].rank == 'Ace':
                has_ace=True
            else:
                has_ace=False
        return has_ace

    def ace_count(self):
        self.ace_count=0
        for l in range(0, len(self.hand)):
            if self.hand[l].rank == 'Ace':
                self.ace_count=self.ace_count+1
            else:
                pass
        return self.ace_count
    
    def clear_hand(self):
        self.hand.clear()

# %%
class Dealer():
    def __init__(self):
        self.hand = []
        self.chips = 10000000 
        self.hand_val= 0
    
    def __str__(self): 
        return "The Dealer has: " + self.hand_print() + "\n"
        
    def hand_print(self):
        final_hand_string = ""
        for i in range(0, len(self.hand)):
            addition = str(self.hand[i])+", "
            final_hand_string=final_hand_string+addition
        return final_hand_string[0:-2]

    def bet(self,bet): 
        self.bet_val = bet
        self.chips=self.chips-self.bet_val
        return int(self.bet_val)
        
    def add_to_chips(self, val_chips): 
        self.val_chips = val_chips
        self.chips = self.chips + self.val_chips
    
    def hand_calc(self):
        self.hand_val=0
        for j in range(0, len(self.hand)):
            self.hand_val=self.hand[j].value+self.hand_val
        
        return self.hand_val
    
    def ace_check(self):
        has_ace = False
        for k in range(0, len(self.hand)):
            if self.hand[k].rank == 'Ace':
                has_ace=True
            else:
                has_ace=False
        return has_ace

    def ace_count(self):
        self.ace_count=0
        for l in range(0, len(self.hand)):
            if self.hand[l].rank == 'Ace':
                self.ace_count=self.ace_count+1
            else:
                pass
        return self.ace_count

    def clear_hand(self):
        self.hand.clear()

# %%
class Pot():
    def __init__(self):
        self.pot_chips = 0
    
    def __str__(self): 
        return "The pot is at " + str(self.pot_chips) + " chips"
    
    def add_to_pot(self, val): 
        self.val = val
        self.pot_chips = self.pot_chips + self.val
    
    def remove_from_pot(self): 
        self.val_chips = self.pot_chips
        self.pot_chips = self.pot_chips - self.val_chips
        return self.val_chips
    
    def remove_half_from_pot(self): 
        self.half_val_chips = self.pot_chips/2
        self.pot_chips = self.pot_chips - self.half_val_chips
        return self.half_val_chips

# %%
################################################# TEST CASES #######################################

# #card creation
# test_deck=Deck()
# # print(test_deck.all_cards[51])

# #deck manipulation
# #test_deck.shuffle() 
# print(test_deck.all_cards[0])
# print(test_deck.all_cards[13])

# #player tests
# # test_player = Player()
# # test_player.hand.append(test_deck.all_cards[0])
# # test_player.hand.append(test_deck.all_cards[13])
# # test_player.hand.clear()

# # test_player.hand.append(test_deck.all_cards[0])
# # test_player.hand.append(test_deck.all_cards[1])


# # print(str(test_player.hand))
# # print(test_player.hand[1])
# # print(test_player.hand[0].value)
# # print(test_player.hand[1].value)
# print(test_player.hand_calc())
# my_value=test_player.hand_calc()

# print(my_value)
# # print(test_player.ace_check())
# # print(test_player.ace_count())

# # #Putting bet in pot
# # test_pot = Pot() 

# # test_pot.add_to_pot(test_player.bet())

# # print(str(test_player))

# # #putting pot winnings in player
# # test_player.add_to_chips(test_pot.remove_from_pot())
# # print(str(test_player))

# %%
#The Game
def black_jack():
    new_deck = Deck()
    new_deck.shuffle()
    player= Player() 
    dealer= Dealer()
    pot= Pot()
    bust_val=21
    game_on = True

    while game_on == True:
        player_bet = player.bet()
        pot.add_to_pot(player_bet)
        pot.add_to_pot(dealer.bet(player_bet))
        player.hand.append(new_deck.deal())
        dealer.hand.append(new_deck.deal())
        player.hand.append(new_deck.deal())
        dealer.hand.append(new_deck.deal())
        player_hit='N'
        my_print(player)
        my_print(dealer)
        
        player_hit=input('Would you like to hit? If so, respond with Y')
        game_continue=True


        if game_continue==True:
            player_hand_value=player.hand_calc()
            while player_hit=='Y':
                player.hand.append(new_deck.deal())
                player_hand_value=player.hand_calc()
                my_print(player)
                
                if player.ace_check() and player_hand_value>21:
                    player_hand_value=player_hand_value-10*(player.ace_count())

                else: 
                    player_hand_value=player_hand_value

                if player_hand_value<bust_val: 
                    player_hit=input('Would you like to hit again? If so respond with Y')
                    
                elif player_hand_value>bust_val:
                    print("Sorry, you busted. You lose")
                    dealer.add_to_chips(pot.remove_from_pot())
                    game_continue = False
                    break

                else:
                    payer_hit=input('Would you like to hit again? If so respond with Y')
                
        
        if game_continue==True:
            dealer_hand_value=dealer.hand_calc()
            while dealer_hand_value<17:
                dealer_hand_value=dealer.hand_calc()
                my_print(dealer)

                if dealer.ace_check() and dealer_hand_value>21:
                    dealer_hand_value = dealer_hand_value - 10*(dealer.ace_count())
                else: 
                    dealer_hand_value = dealer_hand_value
                
                if dealer_hand_value>bust_val:
                    print('Congratulations! Dealer Busts. You won')
                    player.add_to_chips(pot.remove_from_pot())
                    game_continue = False
                    break
                dealer.hand.append(new_deck.deal())

        if game_continue==True:
            if player_hand_value > dealer_hand_value:
                print('Congratulations you won!')
                player.add_to_chips(pot.remove_from_pot())
            
            elif player_hand_value == dealer_hand_value: 
                print('Draw, no winner')
                dealer.add_to_chips(pot.remove_half_from_pot())
                player.add_to_chips(pot.remove_half_from_pot())
            
            else: 
                print('Sorry you lose!')
                dealer.add_to_chips(pot.remove_from_pot())
        
        player_hand_value=0
        dealer_hand_value=0
        player.clear_hand()
        dealer.clear_hand()   
        game_on=new_game()

# %%
black_jack()
# Out:
# The Player has: Six of Diamonds, Nine of Spades
# The Dealer has: King of Spades, Three of Hearts
# The Player has: Six of Diamonds, Nine of Spades, Ace of Clubs
# The Dealer has: King of Spades, Three of Hearts
# The Dealer has: King of Spades, Three of Hearts, Ace of Hearts
# The Dealer has: King of Spades, Three of Hearts, Ace of Hearts, King of Diamonds
# Congratulations! Dealer Busts. You won
# The Player now has: 155 chips
